# %% [markdown]
# ## 顺序：
# - 按照以下顺序做实验，越往前越重要
# - 后面的没时间可以不做
# - 无标度
# - 小世界
# - ER随机图
# - 规则图

# %% [markdown]
# ## 规则图
# - 30 nodes
# - degree of each node = 4

# %%
import networkx as nx
import matplotlib.pyplot as plt
# regular graphy
# generate a regular graph which has 30 nodes & each node has 4 neghbour nodes.
RG = nx.random_graphs.random_regular_graph(4, 30)
# the spectral layout
pos = nx.spectral_layout(RG)
# draw the regular graphy
nx.draw(RG, pos, with_labels = False, node_size = 100)
plt.show()

# %% [markdown]
# ## ER随机图
# - 30 nodes
# - connet a random pair with probility = 0.1

# %%
import networkx as nx
import matplotlib.pyplot as plt
 
# erdos renyi graph
# generate a graph which has n=50 nodes, probablity p = 0.1.
ER = nx.random_graphs.erdos_renyi_graph(30, 0.15)
print(ER.number_of_edges())
# the shell layout
pos = nx.shell_layout(ER)
nx.draw(ER, pos, with_labels = False, node_size = 100)
plt.show()
# Out:
# 66

# %% [markdown]
# ## 小世界
# - 30 nodes
# - each node has 4 neighbour nodes
# - random reconnection probability was 0.3.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# WS network

# generate a WS network which has 50 nodes,
# each node has 4 neighbour nodes,
# random reconnection probability was 0.3.
WS = nx.random_graphs.watts_strogatz_graph(30, 4, 0.3)
print(WS.number_of_edges())
# circular layout
pos = nx.circular_layout(WS)
nx.draw(WS, pos, with_labels = False, node_size = 100)
plt.show()
# Out:
# 60

# %% [markdown]
# ## 无标度
# - 30 nodes
# - add 2 edge each time

# %%
import networkx as nx
import matplotlib.pyplot as plt

# BA scale-free degree network
# generalize BA network which has 30 nodes, m = 2
BA = nx.random_graphs.barabasi_albert_graph(30, 2)
print(BA.number_of_edges())
# spring layout
pos = nx.spring_layout(BA)
nx.draw(BA, pos, with_labels = False, node_size = 30)
plt.show()
# Out:
# 56
